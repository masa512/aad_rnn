# %%
# %reload_ext autoreload
# %autoreload 2
from kalman import *
import matplotlib.pyplot as plt
from time import time

# %%
# Load AAD data
data = AAD_data('S1.mat',k=1)
X,Y = data['eeg'],data['env']
label = data['lab']
print(data['env'][0].shape)
print(data['eeg'].shape)
print(data['lab'])
# Out:
# (12512, 1)
# (12512, 64)
# 1

# %% [markdown]
# # Test RLS

# %%
y = RLS_AAD(X,Y,lambd=1,delta=0.01,up_rate = 1000)
# Out:
# 0 1.0
# 0 0.26599850070010866
# 0 0.3282508504013306
# 0 0.26751666099767984
# 0 0.2685618870209715
# 0 0.26111160635122777
# 0 0.29738652731179865
# 0 0.2726849375337724
# 0 0.2805584026761151
# 0 0.2757603720298458
# 0 0.2685608599593802
# 0 0.2644990795082669
# 0 0.25236032729081626
# 0 0.2511264737244865
# 0 0.24278739909376562
# 0 0.24252905066029198
# 0 0.24030982078072982
# 0 0.23761158671453675
# 0 0.18345338742205133
# 0 0.1773842379823542
# 0 0.17320320321239516
# 0 0.16353728051721317
# 0 0.15545461749454115
# 0 0.15934424863423724
# 0 0.1618903096545032
# 0 0.1566407944568302
# 0 0.16104027011327823
# 0 0.16568206156959403
# 0 0.16565835506996515
# 0 0.1686420893715759
# 0 0.1676781616374844
# 0 0.16861337998599524
# 0 0.17338829880874587
# 0 0.1770412517061095
# 0 0.17618293411871097
# 0 0.18117721159566733
# 0 0.17783698854330346
# 0 0.17407204391271497
# 0 0.1748607476061825
# 0 0.1769089221790635
# 0 0.17528614268779769
# 0 0.1737562835811597
# 0 0.17934304269304124
# ...
